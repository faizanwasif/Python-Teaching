# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
x = ["Practice", "More Practice", "Continue with course"]
y = [1, 35, 5]

# %%
plt.bar(x,y)
plt.show()

# %%
plt.scatter(x, y)
